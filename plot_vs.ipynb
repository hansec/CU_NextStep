# %%
import matplotlib.pyplot as plt
import numpy as np
import cmasher as cmr

# %%
## FAKE WALL NO PLATE
gtw_noplate = np.array([5.49762734, 5.96917096, 6.87318954, 7.73195899, 8.90092654,
       4.88225648, 5.64273783, 6.06724115, 7.0932562 , 8.15876676,
       3.63783255, 4.15708014, 4.87216744, 5.69814863, 6.64519791,
       2.51110247, 3.10513046, 3.71757199, 4.46237626, 5.12607168,
       1.91950344, 2.4618795 , 2.98772204, 3.53476452, 4.02312608])

# %%
deltas = np.array([-0.7218842914744313, -0.7211707714760555, -0.7219159523101958, -0.7252743273414322, -0.7305856169141514, -0.620628018508975, -0.6192372634274822, -0.6198931453438137, -0.6205447427373194, -0.6263054498575995, -0.5151948754956394, -0.5158344342962164, -0.5158881043385357, -0.5171687516433744, -0.5185513297528541, -0.40561841559069006, -0.40766659905860864, -0.41147499799739223, -0.4146750903186826, -0.4165251160000698, -0.2976229924431968, -0.3003599597404068, -0.30471761876646525, -0.3102944056193635, -0.3162843762247405])
kappas = np.array([1.5136871752293546, 1.6095920616669332, 1.7067816601129118, 1.8075126697290222, 1.9098785003055228, 1.5043711601946483, 1.6040885550482722, 1.7050135417538175, 1.8059275580124163, 1.9140410183532268, 1.487412114104861, 1.5879812615847093, 1.6911957660813357, 1.7945443399619465, 1.899319307311534, 1.4819968065715259, 1.5827242393855048, 1.680867933027843, 1.7802819114982178, 1.8808639741554734, 1.481374459314057, 1.5829265392537908, 1.6813069105317315, 1.7762168018570361, 1.8668135078399148])

# %%
import matplotlib as mpl
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'
cmap = mpl.cm.plasma(np.linspace(0,1,100))
cmap = mpl.colors.ListedColormap(cmap[:,:-1])
from matplotlib.colors import LinearSegmentedColormap
colors = ["rebeccapurple","mediumpurple", "royalblue", "lightseagreen", "mediumaquamarine"]
colors = ["darkslateblue","mediumslateblue","hotpink","orange", "gold"]
nodes = [0.,0.22,  0.5, 0.78,1]
cmap1 = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))
cmap = cmr.bubblegum
norm = plt.Normalize(np.min(gtw), np.max(gtw))
c = cmap(norm(gtw))
for i in range(len(deltas)):
    plt.scatter(deltas[i],kappas[i], color = c[i], s = 45)

sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = plt.gca())
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 20)
plt.grid()
plt.xlabel(r'$\delta$', size = 20)
plt.ylabel(r'$\kappa$', size = 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#      10 cmap1 = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))
#      11 cmap = cmr.bubblegum
# ---> 12 norm = plt.Normalize(np.min(gtw), np.max(gtw))
#      13 c = cmap(norm(gtw))
#      14 for i in range(len(deltas)):
#
# NameError: name 'gtw' is not defined

# %%
######FAKE WALL + PLATE
gtw_plate = np.array([1.00427686, 1.15053183, 1.41067778, 1.7639982 , 2.16201551,
       0.92561208, 1.08439377, 1.31408228, 1.57545728, 1.88816747,
       0.74318259, 0.89281246, 1.09503528, 1.34645475, 1.64350534,
       0.57314108, 0.71673845, 0.90077766, 1.1183936 , 1.38162961,
       0.44219215, 0.57688382, 0.74169712, 0.94202629, 1.13544563])

# %%
import matplotlib as mpl
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'
cmap = mpl.cm.plasma(np.linspace(0,1,100))
cmap = mpl.colors.ListedColormap(cmap[:,:-1])
from matplotlib.colors import LinearSegmentedColormap
colors = ["rebeccapurple","mediumpurple", "royalblue", "lightseagreen", "mediumaquamarine"]
colors = ["darkslateblue","mediumslateblue","hotpink","orange", "gold"]
nodes = [0.,0.22,  0.5, 0.78,1]
cmap1 = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))
cmap = cmr.bubblegum
norm = plt.Normalize(np.min(gtw), np.max(gtw))
c = cmap(norm(gtw))
for i in range(len(deltas)):
    plt.scatter(deltas[i],kappas[i], color = c[i], s = 45)

sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = plt.gca())
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 20)
plt.grid()
plt.xlabel(r'$\delta$', size = 20)
plt.ylabel(r'$\kappa$', size = 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 12
#      10 cmap1 = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))
#      11 cmap = cmr.bubblegum
# ---> 12 norm = plt.Normalize(np.min(gtw), np.max(gtw))
#      13 c = cmap(norm(gtw))
#      14 for i in range(len(deltas)):
#
# NameError: name 'gtw' is not defined

# %%
#### SINGLE NULL
deltas = np.array([-0.7067167092246878, -0.6866732760756474, -0.6523879442799727, -0.6097977498476748, -0.5770535071582983, -0.5676745873056612, -0.552896406041337, -0.5313042546838588, -0.492820057262884, -0.48147634980484344, -0.46940954375935484, -0.45311244410355767, -0.4069549507821722, -0.3998066133797767, -0.38429753644695486, -0.3708056930097567, -0.31953495438440044, -0.3097536288753963, -0.3007595196577602, -0.2857095967894999])
kappas = np.array([1.470845319891801, 1.5612948099297783, 1.6506603905775614, 1.741364244106647, 1.4833951002697956, 1.5763703761353154, 1.6689847577988208, 1.7618844034238474, 1.4912880297810966, 1.5856724650739067, 1.6802593941931354, 1.7751149549103187, 1.4956672531308715, 1.5890480270011094, 1.6846005712148833, 1.7804415843481936, 1.5033891411658284, 1.5958317388979044, 1.6880224939300847, 1.7821631058760026])
gtw = np.array([2.52310786, 2.92825494, 3.30801036, 3.65196433, 2.05890478,
       2.47283931, 2.87545147, 3.22499173, 1.72668202, 2.06933303,
       2.41506347, 2.71523698, 1.4209097 , 1.73645938, 2.05878541,
       2.3212575 , 1.20071824, 1.48160583, 1.75342594, 2.0119228 ])

import matplotlib as mpl
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'
cmap = mpl.cm.plasma(np.linspace(0,1,100))
cmap = mpl.colors.ListedColormap(cmap[:,:-1])
from matplotlib.colors import LinearSegmentedColormap
colors = ["rebeccapurple","mediumpurple", "royalblue", "lightseagreen", "mediumaquamarine"]
colors = ["darkslateblue","mediumslateblue","hotpink","orange", "gold"]
nodes = [0.,0.22,  0.5, 0.78,1]
cmap1 = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))
cmap = cmr.bubblegum
norm = plt.Normalize(np.min(gtw), np.max(gtw))
c = cmap(norm(gtw))
for i in range(len(deltas)):
    plt.scatter(deltas[i],kappas[i], color = c[i], s = 45)

sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = plt.gca())
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 20)
plt.grid()
plt.xlabel(r'$\delta$', size = 20)
plt.ylabel(r'$\kappa$', size = 20)
# Out:
# Text(0, 0.5, '$\\kappa$')

# %%
## REAL WALL WITH PLATES
gammas = np.array([-361.4498558643463, -419.8863332934052, -543.0549884941793, -719.464169544568, -983.2649804180837, -334.92331693067536, -395.8445834930608, -482.10196768024616, -619.2237493806169, -811.7053766155877, -256.1418404075448, -308.4974311163969, -390.7125204582917, -500.5326454751921, -646.0234546501888, -183.02511321613565, -238.29600443421077, -300.2802749123366, -385.63874414433667, -506.00015776083455, -131.82372200547252, -173.78769200608076, -241.59895258587494, -310.4812080864649, -394.2430251760961])
tau = 0.005815214792339728
gtw_plate_wall = -tau*gammas
deltas = np.array([-0.7218842914744313, -0.7211707714760555, -0.7219159523101958, -0.7252743273414322, -0.7305856169141514, -0.620628018508975, -0.6192372634274822, -0.6198931453438137, -0.6205447427373194, -0.6263054498575995, -0.5151948754956394, -0.5158344342962164, -0.5158881043385357, -0.5171687516433744, -0.5185513297528541, -0.40561841559069006, -0.40766659905860864, -0.41147499799739223, -0.4146750903186826, -0.4165251160000698, -0.2976229924431968, -0.3003599597404068, -0.30471761876646525, -0.3102944056193635, -0.3162843762247405])
kappas = np.array([1.5136871752293546, 1.6095920616669332, 1.7067816601129118, 1.8075126697290222, 1.9098785003055228, 1.5043711601946483, 1.6040885550482722, 1.7050135417538175, 1.8059275580124163, 1.9140410183532268, 1.487412114104861, 1.5879812615847093, 1.6911957660813357, 1.7945443399619465, 1.899319307311534, 1.4819968065715259, 1.5827242393855048, 1.680867933027843, 1.7802819114982178, 1.8808639741554734, 1.481374459314057, 1.5829265392537908, 1.6813069105317315, 1.7762168018570361, 1.8668135078399148])

# %%
import matplotlib as mpl
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'
cmap = mpl.cm.plasma(np.linspace(0,1,100))
cmap = mpl.colors.ListedColormap(cmap[:,:-1])
from matplotlib.colors import LinearSegmentedColormap
colors = ["rebeccapurple","mediumpurple", "royalblue", "lightseagreen", "mediumaquamarine"]
colors = ["darkslateblue","mediumslateblue","hotpink","orange", "gold"]
nodes = [0.,0.22,  0.5, 0.78,1]
cmap1 = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))
cmap = cmr.bubblegum
norm = plt.Normalize(np.min(gtw), np.max(gtw))
c = cmap(norm(gtw))
for i in range(len(deltas)):
    plt.scatter(deltas[i],kappas[i], color = c[i], s = 45)

sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = plt.gca())
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 20)
plt.grid()
plt.xlabel(r'$\delta$', size = 20)
plt.ylabel(r'$\kappa$', size = 20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 15
#      13 c = cmap(norm(gtw))
#      14 for i in range(len(deltas)):
# ---> 15     plt.scatter(deltas[i],kappas[i], color = c[i], s = 45)
#      17 sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
#      18 cb = plt.colorbar(sm, ax = plt.gca())
#
# IndexError: index 20 is out of bounds for axis 0 with size 20

# %%
vv_out_fake = np.array([[ 1.39296493e+00, -1.38777878e-17],
       [ 1.38817072e+00,  1.14458731e-01],
       [ 1.37399275e+00,  2.30041200e-01],
       [ 1.35115684e+00,  3.37922814e-01],
       [ 1.32092944e+00,  4.32392306e-01],
       [ 1.28527112e+00,  5.08535482e-01],
       [ 1.24727606e+00,  5.62208864e-01],
       [ 1.21192830e+00,  5.91145285e-01],
       [ 1.18207641e+00,  5.99489787e-01],
       [ 1.08796580e+00,  5.88215468e-01],
       [ 9.88631600e-01,  5.53365296e-01],
       [ 8.94802348e-01,  4.96559420e-01],
       [ 8.11223325e-01,  4.20071879e-01],
       [ 7.41877594e-01,  3.27189432e-01],
       [ 6.89999158e-01,  2.22153185e-01],
       [ 6.57963346e-01,  1.10225658e-01],
       [ 6.47190584e-01, -6.93889390e-18],
       [ 6.57963346e-01, -1.10225658e-01],
       [ 6.89999158e-01, -2.22153185e-01],
       [ 7.41877594e-01, -3.27189432e-01],
       [ 8.11223325e-01, -4.20071879e-01],
       [ 8.94802348e-01, -4.96559420e-01],
       [ 9.88631600e-01, -5.53365296e-01],
       [ 1.08796580e+00, -5.88215468e-01],
       [ 1.18207641e+00, -5.99489787e-01],
       [ 1.21192830e+00, -5.91145285e-01],
       [ 1.24727606e+00, -5.62208864e-01],
       [ 1.28527112e+00, -5.08535482e-01],
       [ 1.32092944e+00, -4.32392306e-01],
       [ 1.35115684e+00, -3.37922814e-01],
       [ 1.37399275e+00, -2.30041200e-01],
       [ 1.38817072e+00, -1.14458731e-01]])

vv_in_fake = np.array([[ 1.38295616,  0.        ],
       [ 1.37819627,  0.1136394 ],
       [ 1.36411987,  0.22839392],
       [ 1.34147837,  0.33535708],
       [ 1.31160087,  0.428733  ],
       [ 1.27659351,  0.50348616],
       [ 1.23989537,  0.55532746],
       [ 1.20721657,  0.58207902],
       [ 1.18129551,  0.58932473],
       [ 1.0902428 ,  0.57841675],
       [ 0.99292215,  0.544273  ],
       [ 0.90082552,  0.48851609],
       [ 0.81867131,  0.41333246],
       [ 0.75043826,  0.32194035],
       [ 0.69936479,  0.2185339 ],
       [ 0.66782749,  0.10834806],
       [ 0.65723823,  0.        ],
       [ 0.66782749, -0.10834806],
       [ 0.69936479, -0.2185339 ],
       [ 0.75043826, -0.32194035],
       [ 0.81867131, -0.41333246],
       [ 0.90082552, -0.48851609],
       [ 0.99292215, -0.544273  ],
       [ 1.0902428 , -0.57841675],
       [ 1.18129551, -0.58932473],
       [ 1.20721657, -0.58207902],
       [ 1.23989537, -0.55532746],
       [ 1.27659351, -0.50348616],
       [ 1.31160087, -0.428733  ],
       [ 1.34147837, -0.33535708],
       [ 1.36411987, -0.22839392],
       [ 1.37819627, -0.1136394 ]])

vv_out = np.array([[1530.65148926,  220.        ],
       [1500.63879395,  220.        ],
       [1500.63879395,  200.        ],
       [1399.87316895,  200.        ],
       [1399.84533691,  256.60427856],
       [1472.52368164,  279.62091064],
       [1481.43310547,  251.49797058],
       [1500.50280762,  257.53723145],
       [1435.56945801,  462.50097656],
       [1416.49975586,  456.46173096],
       [1425.40930176,  428.33880615],
       [1399.84533691,  420.24295044],
       [1399.87207031,  470.        ],
       [1289.99987793,  470.00009155],
       [1289.99975586,  635.        ],
       [1068.09130859,  635.        ],
       [1068.09130859,  744.92041016],
       [1102.09423828,  744.92041016],
       [1102.09423828,  764.92041016],
       [ 877.07501221,  764.92041016],
       [ 877.07501221,  744.92041016],
       [ 887.0758667 ,  744.92041016],
       [ 887.0758667 ,  635.        ],
       [ 869.95117188,  635.        ],
       [ 869.95117188,  470.        ],
       [ 658.95697021,  470.        ],
       [ 658.95697021, -470.        ],
       [ 869.95117188, -470.        ],
       [ 869.95117188, -635.        ],
       [ 887.0758667 , -635.        ],
       [ 887.0758667 , -744.92041016],
       [ 877.07501221, -744.92041016],
       [ 877.07501221, -764.92041016],
       [1073.09191895, -764.92059326],
       [1073.09191895, -744.92059326],
       [1068.09130859, -744.92041016],
       [1068.09130859, -635.        ],
       [1289.99975586, -635.        ],
       [1289.99987793, -470.00009155],
       [1399.87207031, -470.        ],
       [1399.88354492, -443.76760864],
       [1455.8515625 , -462.43685913],
       [1452.05419922, -473.82019043],
       [1471.02697754, -480.14892578],
       [1527.98706055, -309.39849854],
       [1509.01428223, -303.06976318],
       [1505.21691895, -314.453125  ],
       [1399.88354492, -279.31704712],
       [1399.87316895, -200.        ],
       [1500.63879395, -200.        ],
       [1500.63879395, -220.        ],
       [1530.65148926, -220.        ]])

vv_in = np.array([[1500.63879395,  195.        ],
       [1392.3737793 ,  195.        ],
       [1389.87475586,  200.        ],
       [1389.85327148,  256.5866394 ],
       [1471.61755371,  282.48086548],
       [1426.31530762,  425.47885132],
       [1389.85327148,  413.93151855],
       [1389.87304688,  460.        ],
       [1279.95019531,  460.        ],
       [1279.95019531,  625.        ],
       [1065.09118652,  625.        ],
       [1065.09106445,  744.92041016],
       [ 890.07617188,  744.92041016],
       [ 890.07617188,  625.        ],
       [ 879.95056152,  625.        ],
       [ 879.95056152,  460.        ],
       [ 669.24145508,  460.        ],
       [ 669.24145508, -460.        ],
       [ 879.95056152, -460.        ],
       [ 879.95056152, -625.        ],
       [ 890.07617188, -625.        ],
       [ 890.07617188, -744.92041016],
       [1065.09106445, -744.92041016],
       [1065.09118652, -625.        ],
       [1279.95019531, -625.        ],
       [1279.95019531, -460.        ],
       [1389.87304688, -460.        ],
       [1389.88684082, -437.27053833],
       [1456.80090332, -459.59100342],
       [1504.26757812, -317.29898071],
       [1389.88684082, -279.14501953],
       [1389.87475586, -200.        ],
       [1392.3737793 , -195.        ],
       [1500.63879395, -195.        ]])

import json
with open('nsf_geom_new.json','r') as fid:
    nsf_geom = json.load(fid)

# %%
zmax = np.array([-0.11263831040530375, -0.1147849478559654, -0.08827660711976668, -0.5471712769970382, -0.5557220591932376, -0.10900222297098273, -0.07895390241700229, -0.5847017443046756, -0.5757312923513347, -0.5736674487151439, -0.11316085027912381, -0.12007906214506985, -0.11513654133967863, -0.08941735950628274, -0.5111625273345611, -0.12440081774578957, -0.597598023131603, -0.5976546586720561, -0.5730581191594779, -0.5990179973617772,-0.12026287368780011, -0.135891718636477,-0.1286621428730263,-0.5966685630516679, -0.5868125561507398])
import matplotlib as mpl
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'
cmap = mpl.cm.plasma(np.linspace(0,1,100))
cmap = mpl.colors.ListedColormap(cmap[:,:-1])
from matplotlib.colors import LinearSegmentedColormap
colors = ["rebeccapurple","mediumpurple", "royalblue", "lightseagreen", "mediumaquamarine"]
colors = ["darkslateblue","mediumslateblue","hotpink","orange", "gold"]
nodes = [0.,0.22,  0.5, 0.78,1]
cmap1 = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))
cmap = cmr.bubblegum
norm = plt.Normalize(np.min(zmax), np.max(zmax))
c = cmap(norm(zmax))
for i in range(len(deltas)):
    plt.scatter(deltas[i],kappas[i], color = c[i], s = 45)

sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = plt.gca())
cb.set_label(label = r'$z_\mathrm{max}$ (m)', size = 20)
plt.grid()
plt.xlabel(r'$\delta$', size = 20)
plt.ylabel(r'$\kappa$', size = 20)
# Out:
# Text(0, 0.5, '$\\kappa$')

# %%
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'

from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec
fig = plt.figure(figsize=(6.2,8 ))
gs0 = GridSpec(3, 2, figure=fig, width_ratios = [1, 1.5], wspace = 0.2 )


ax0 = fig.add_subplot(gs0[0,0])
ax1 = fig.add_subplot(gs0[1,0])
ax2 = fig.add_subplot(gs0[2,0])
ax3 = fig.add_subplot(gs0[0,1])
ax4 = fig.add_subplot(gs0[1,1])
ax5 = fig.add_subplot(gs0[2,1])

ax0.set_aspect(aspect = 1)
ax1.set_aspect(aspect = 1)
ax2.set_aspect(aspect = 1)


ax0.fill(vv_out_fake[:,0], vv_out_fake[:,1], color = 'k')
ax0.fill(vv_in_fake[:,0], vv_in_fake[:,1], color = 'w')

ax1.fill(vv_out_fake[:,0], vv_out_fake[:,1], color = 'k')
ax1.fill(vv_in_fake[:,0], vv_in_fake[:,1], color = 'w')

ax2.fill(vv_out[:,0]/1000, vv_out[:,1]/1000, color = 'k')
ax2.fill(vv_in[:,0]/1000, vv_in[:,1]/1000, color = 'w')

ax0.set_xlim([0.5,1.6])
ax1.set_xlim([0.5,1.6])
ax2.set_xlim([0.5,1.6])

ax1.fill((np.array(nsf_geom['in_upper_plate'])/1000)[:,0], (np.array(nsf_geom['in_upper_plate'])/1000)[:,1], color = 'dodgerblue')
ax1.fill((np.array(nsf_geom['in_lower_plate'])/1000)[:,0], (np.array(nsf_geom['in_lower_plate'])/1000)[:,1], color = 'dodgerblue')
ax1.fill((np.array(nsf_geom['out_upper_plate'])/1000)[:,0], (np.array(nsf_geom['out_upper_plate'])/1000)[:,1], color = 'dodgerblue')
ax1.fill((np.array(nsf_geom['out_lower_plate'])/1000)[:,0], (np.array(nsf_geom['out_lower_plate'])/1000)[:,1], color = 'dodgerblue')

ax2.fill((np.array(nsf_geom['in_upper_plate'])/1000)[:,0], (np.array(nsf_geom['in_upper_plate'])/1000)[:,1], color = 'dodgerblue')
ax2.fill((np.array(nsf_geom['in_lower_plate'])/1000)[:,0], (np.array(nsf_geom['in_lower_plate'])/1000)[:,1], color = 'dodgerblue')
ax2.fill((np.array(nsf_geom['out_upper_plate'])/1000)[:,0], (np.array(nsf_geom['out_upper_plate'])/1000)[:,1], color = 'dodgerblue')
ax2.fill((np.array(nsf_geom['out_lower_plate'])/1000)[:,0], (np.array(nsf_geom['out_lower_plate'])/1000)[:,1], color = 'dodgerblue')

ax2.set_xlabel('R (m)', fontsize = 16)

ax0.set_ylabel('Z (m)', fontsize = 16)
ax1.set_ylabel('Z (m)', fontsize = 16)
ax2.set_ylabel('Z (m)', fontsize = 16)

cmap = cmr.bubblegum
norm = plt.Normalize(np.min(gtw_noplate), np.max(gtw_noplate))
c = cmap(norm(gtw_noplate))
for i in range(len(deltas)):
    ax3.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax3)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax3.grid()
#ax3.set_xlabel(r'$\delta$', size = 16)
ax3.set_ylabel(r'$\kappa$', size = 16)

norm = plt.Normalize(np.min(gtw_plate), np.max(gtw_plate))
c = cmap(norm(gtw_plate))
for i in range(len(deltas)):
    ax4.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax4)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax4.grid()
#ax4.set_xlabel(r'$\delta$', size = 16)
ax4.set_ylabel(r'$\kappa$', size = 16)

norm = plt.Normalize(np.min(gtw_plate_wall), np.max(gtw_plate_wall))
c = cmap(norm(gtw_plate_wall))
for i in range(len(deltas)):
    ax5.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax5)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax5.grid()
ax5.set_xlabel(r'$\delta$', size = 16)
ax5.set_ylabel(r'$\kappa$', size = 16)


ax0.set_ylim([-0.85,0.85])
ax1.set_ylim([-0.85,0.85])
ax2.set_ylim([-0.85,0.85])

ax3.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])
ax4.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])
ax5.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])

ax0.text(0.53, 0.64, '(a)', fontsize = 16)
ax1.text(0.53, 0.64, '(b)', fontsize = 16)
ax2.text(0.53, 0.64, '(c)', fontsize = 16)
# Out:
# Text(0.53, 0.64, '(c)')

# %%
import sys
sys.path.append('/Applications/OpenFUSIONToolkit/python')
from OpenFUSIONToolkit.TokaMaker.util import create_isoflux, read_eqdsk

plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'

from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec
fig = plt.figure(figsize=(6.3,10 ))
gs0 = GridSpec(3, 2, figure=fig, width_ratios = [1, 1.3], wspace = 0.25 )


ax0 = fig.add_subplot(gs0[0,0])
ax1 = fig.add_subplot(gs0[1,0])
ax2 = fig.add_subplot(gs0[2,0])
ax3 = fig.add_subplot(gs0[0,1])
ax4 = fig.add_subplot(gs0[1,1])
ax5 = fig.add_subplot(gs0[2,1])

ax0.set_aspect(aspect = 1)
ax1.set_aspect(aspect = 1)
ax2.set_aspect(aspect = 1)


ax0.fill(vv_out_fake[:,0], vv_out_fake[:,1], color = 'k')
ax0.fill(vv_in_fake[:,0], vv_in_fake[:,1], color = 'w')

ax1.fill(vv_out_fake[:,0], vv_out_fake[:,1], color = 'k')
ax1.fill(vv_in_fake[:,0], vv_in_fake[:,1], color = 'w')

ax2.fill(vv_out[:,0]/1000, vv_out[:,1]/1000, color = 'k')
ax2.fill(vv_in[:,0]/1000, vv_in[:,1]/1000, color = 'w')

ax0.set_xlim([0.5,1.6])
ax1.set_xlim([0.5,1.6])
ax2.set_xlim([0.5,1.6])

ax1.fill((np.array(nsf_geom['in_upper_plate'])/1000)[:,0], (np.array(nsf_geom['in_upper_plate'])/1000)[:,1], color = 'k')
ax1.fill((np.array(nsf_geom['in_lower_plate'])/1000)[:,0], (np.array(nsf_geom['in_lower_plate'])/1000)[:,1], color = 'k')
ax1.fill((np.array(nsf_geom['out_upper_plate'])/1000)[:,0], (np.array(nsf_geom['out_upper_plate'])/1000)[:,1], color = 'k')
ax1.fill((np.array(nsf_geom['out_lower_plate'])/1000)[:,0], (np.array(nsf_geom['out_lower_plate'])/1000)[:,1], color = 'k')

ax2.fill((np.array(nsf_geom['in_upper_plate'])/1000)[:,0], (np.array(nsf_geom['in_upper_plate'])/1000)[:,1], color = 'k')
ax2.fill((np.array(nsf_geom['in_lower_plate'])/1000)[:,0], (np.array(nsf_geom['in_lower_plate'])/1000)[:,1], color = 'k')
ax2.fill((np.array(nsf_geom['out_upper_plate'])/1000)[:,0], (np.array(nsf_geom['out_upper_plate'])/1000)[:,1], color = 'k')
ax2.fill((np.array(nsf_geom['out_lower_plate'])/1000)[:,0], (np.array(nsf_geom['out_lower_plate'])/1000)[:,1], color = 'k')

ax2.set_xlabel('R (m)', fontsize = 16)

ax0.set_ylabel('Z (m)', fontsize = 16)
ax1.set_ylabel('Z (m)', fontsize = 16)
ax2.set_ylabel('Z (m)', fontsize = 16)

cmap = cmr.bubblegum
norm = plt.Normalize(np.min(gtw_noplate), np.max(gtw_noplate))
c = cmap(norm(gtw_noplate))
label = ['g_-0.7_1.5', 'g_-0.7_1.6', 'g_-0.7_1.7','g_-0.7_1.7999999999999998', 'g_-0.7_1.9', 'g_-0.6_1.5', 'g_-0.6_1.6',  'g_-0.6_1.7', 'g_-0.6_1.7999999999999998', 'g_-0.6_1.9', 'g_-0.5_1.5', 'g_-0.5_1.6', 'g_-0.5_1.7', 'g_-0.5_1.7999999999999998', 'g_-0.5_1.9', 'g_-0.39999999999999997_1.5', 'g_-0.39999999999999997_1.6', 'g_-0.39999999999999997_1.7', 'g_-0.39999999999999997_1.7999999999999998', 'g_-0.39999999999999997_1.9', 'g_-0.3_1.5', 'g_-0.3_1.6', 'g_-0.3_1.7', 'g_-0.3_1.7999999999999998', 'g_-0.3_1.9']
for i in range(len(deltas)):
    eq = read_eqdsk(label[i])
    ax0.plot(eq['rzout'][:,0],eq['rzout'][:,1], linewidth = 0.5, color = c[i], alpha = 0.75)
    ax3.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax3)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax3.grid()
#ax3.set_xlabel(r'$\delta$', size = 16)
ax3.set_ylabel(r'$\kappa$', size = 16)

norm = plt.Normalize(np.min(gtw_plate), np.max(gtw_plate))
c = cmap(norm(gtw_plate))
for i in range(len(deltas)):
    eq = read_eqdsk(label[i])
    ax1.plot(eq['rzout'][:,0],eq['rzout'][:,1], linewidth = 0.5, color = c[i], alpha = 0.75)
    ax4.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax4)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax4.grid()
#ax4.set_xlabel(r'$\delta$', size = 16)
ax4.set_ylabel(r'$\kappa$', size = 16)

norm = plt.Normalize(np.min(gtw_plate_wall), np.max(gtw_plate_wall))
c = cmap(norm(gtw_plate_wall))
for i in range(len(deltas)):
    eq = read_eqdsk(label[i])
    ax2.plot(eq['rzout'][:,0],eq['rzout'][:,1], linewidth = 0.5, color = c[i], alpha = 0.75)
    ax5.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax5)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax5.grid()
ax5.set_xlabel(r'$\delta$', size = 16)
ax5.set_ylabel(r'$\kappa$', size = 16)


ax0.set_ylim([-0.85,0.85])
ax1.set_ylim([-0.85,0.85])
ax2.set_ylim([-0.85,0.85])

ax3.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])
ax4.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])
ax5.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])

ax0.text(0.53, 0.68, '(a)', fontsize = 16)
ax1.text(0.53, 0.68, '(b)', fontsize = 16)
ax2.text(0.53, 0.68, '(c)', fontsize = 16)
# Out:
# Text(0.53, 0.68, '(c)')

# %%
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'

from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec
fig = plt.figure(figsize=(6.2,8 ))
gs0 = GridSpec(3, 2, figure=fig, width_ratios = [1, 1.5], wspace = 0.2 )


ax0 = fig.add_subplot(gs0[0,0])
ax1 = fig.add_subplot(gs0[1,0])
ax2 = fig.add_subplot(gs0[2,0])
ax3 = fig.add_subplot(gs0[0,1])
ax4 = fig.add_subplot(gs0[1,1])
ax5 = fig.add_subplot(gs0[2,1])

ax0.set_aspect(aspect = 1)
ax1.set_aspect(aspect = 1)
ax2.set_aspect(aspect = 1)


ax0.fill(vv_out_fake[:,0], vv_out_fake[:,1], color = 'k')
ax0.fill(vv_in_fake[:,0], vv_in_fake[:,1], color = 'w')

ax1.fill(vv_out_fake[:,0], vv_out_fake[:,1], color = 'k')
ax1.fill(vv_in_fake[:,0], vv_in_fake[:,1], color = 'w')

ax2.fill(vv_out[:,0]/1000, vv_out[:,1]/1000, color = 'k')
ax2.fill(vv_in[:,0]/1000, vv_in[:,1]/1000, color = 'w')

ax0.set_xlim([0.5,1.6])
ax1.set_xlim([0.5,1.6])
ax2.set_xlim([0.5,1.6])

ax1.fill((np.array(nsf_geom['in_upper_plate'])/1000)[:,0], (np.array(nsf_geom['in_upper_plate'])/1000)[:,1], color = 'dodgerblue')
ax1.fill((np.array(nsf_geom['in_lower_plate'])/1000)[:,0], (np.array(nsf_geom['in_lower_plate'])/1000)[:,1], color = 'dodgerblue')
ax1.fill((np.array(nsf_geom['out_upper_plate'])/1000)[:,0], (np.array(nsf_geom['out_upper_plate'])/1000)[:,1], color = 'dodgerblue')
ax1.fill((np.array(nsf_geom['out_lower_plate'])/1000)[:,0], (np.array(nsf_geom['out_lower_plate'])/1000)[:,1], color = 'dodgerblue')

ax2.fill((np.array(nsf_geom['in_upper_plate'])/1000)[:,0], (np.array(nsf_geom['in_upper_plate'])/1000)[:,1], color = 'dodgerblue')
ax2.fill((np.array(nsf_geom['in_lower_plate'])/1000)[:,0], (np.array(nsf_geom['in_lower_plate'])/1000)[:,1], color = 'dodgerblue')
ax2.fill((np.array(nsf_geom['out_upper_plate'])/1000)[:,0], (np.array(nsf_geom['out_upper_plate'])/1000)[:,1], color = 'dodgerblue')
ax2.fill((np.array(nsf_geom['out_lower_plate'])/1000)[:,0], (np.array(nsf_geom['out_lower_plate'])/1000)[:,1], color = 'dodgerblue')

ax2.set_xlabel('R (m)', fontsize = 16)

ax0.set_ylabel('Z (m)', fontsize = 16)
ax1.set_ylabel('Z (m)', fontsize = 16)
ax2.set_ylabel('Z (m)', fontsize = 16)

cmap = cmr.bubblegum
norm = plt.Normalize(np.min(gtw_plate), np.max(gtw_noplate))
c = cmap(norm(gtw_noplate))
for i in range(len(deltas)):
    ax3.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax3)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax3.grid()
#ax3.set_xlabel(r'$\delta$', size = 16)
ax3.set_ylabel(r'$\kappa$', size = 16)


c = cmap(norm(gtw_plate))
for i in range(len(deltas)):
    ax4.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax4)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax4.grid()
#ax4.set_xlabel(r'$\delta$', size = 16)
ax4.set_ylabel(r'$\kappa$', size = 16)

c = cmap(norm(gtw_plate_wall))
for i in range(len(deltas)):
    ax5.scatter(deltas[i],kappas[i], color = c[i], s = 25)
sm = plt.cm.ScalarMappable(cmap=cmap, norm = norm)
cb = plt.colorbar(sm, ax = ax5)
cb.set_label(label = r'$\gamma \tau_\mathrm{W}$', size = 16)
ax5.grid()
ax5.set_xlabel(r'$\delta$', size = 16)
ax5.set_ylabel(r'$\kappa$', size = 16)


ax0.set_ylim([-0.85,0.85])
ax1.set_ylim([-0.85,0.85])
ax2.set_ylim([-0.85,0.85])

ax3.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])
ax4.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])
ax5.set_xticks([-0.7, -0.6, -0.5, -0.4, -0.3])
